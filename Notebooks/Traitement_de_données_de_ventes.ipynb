# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url_data = "/content/train.csv"
df = pd.read_csv(url_data)
df.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680

# %% [markdown]
# #Explorer les données

# %%
df.info() # résumé du DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
#  17  Sales          9800 non-null   float64
# dtypes: float64(2), int64(1), object(15)
# memory usage: 1.3+ MB

# %%
df.describe() # stats descriptives
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
df.columns # noms des colonnes
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
df.shape # dimensions
# Out:
# (9800, 18)

# %% [markdown]
# # Nettoyage de base

# %%
#  Renommer les colonnes
df.rename(columns={
    'Row ID': 'ID Ligne',
    'Order ID': 'ID Commande',
    'Order Date': 'Date Commande',
    'Ship Date': 'Date Expedition',
    'Ship Mode': 'Mode Livraison',
    'Customer ID': 'ID Client',
    'Customer Name': 'Nom Client',
    'Segment': 'Segment Client',
    'Country': 'Pays',
    'City': 'Ville',
    'State': 'État',
    'Postal Code': 'Code Postal',
    'Region': 'Région',
    'Product ID': 'ID Produit',
    'Category': 'Catégorie',
    'Sub-Category': 'Sous-Catégorie',
    'Product Name': 'Nom Produit',
    'Sales': 'Ventes'
}, inplace=True)

df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

df.head(5)
# Out:
#    id_ligne     id_commande date_commande date_expédition  mode_livraison  \
# 0         1  CA-2017-152156    08/11/2017      11/11/2017    Second Class
# 1         2  CA-2017-152156    08/11/2017      11/11/2017    Second Class
# 2         3  CA-2017-138688    12/06/2017      16/06/2017    Second Class
# 3         4  US-2016-108966    11/10/2016      18/10/2016  Standard Class
# 4         5  US-2016-108966    11/10/2016      18/10/2016  Standard Class
#
#   id_client       nom_client segment_client           pays            ville  \
# 0  CG-12520      Claire Gute       Consumer  United States        Henderson
# 1  CG-12520      Claire Gute       Consumer  United States        Henderson
# 2  DV-13045  Darrin Van Huff      Corporate  United States      Los Angeles
# 3  SO-20335   Sean O'Donnell       Consumer  United States  Fort Lauderdale
# 4  SO-20335   Sean O'Donnell       Consumer  United States  Fort Lauderdale
#
#          état  code_postal région       id_produit        catégorie  \
# 0    Kentucky      42420.0  South  FUR-BO-10001798        Furniture
# 1    Kentucky      42420.0  South  FUR-CH-10000454        Furniture
# 2  California      90036.0   West  OFF-LA-10000240  Office Supplies
# 3     Florida      33311.0  South  FUR-TA-10000577        Furniture
# 4     Florida      33311.0  South  OFF-ST-10000760  Office Supplies
#
#   sous-catégorie                                        nom_produit    ventes
# 0      Bookcases                  Bush Somerset Collection Bookcase  261.9600
# 1         Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2         Labels  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3         Tables      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4        Storage                     Eldon Fold 'N Roll Cart System   22.3680

# %%
# Gérer les valeurs manquantes

df.isnull().sum()       # nombre de valeurs manquantes par colonne
# Out:
# id_ligne           0
# id_commande        0
# date_commande      0
# date_expédition    0
# mode_livraison     0
# id_client          0
# nom_client         0
# segment_client     0
# pays               0
# ville              0
# état               0
# code_postal        0
# région             0
# id_produit         0
# catégorie          0
# sous-catégorie     0
# nom_produit        0
# ventes             0
# dtype: int64

# %% [markdown]
# Nous constatons que dans la colonne code postale il ya 11 valeurs manquantes , on va devoir les supprimer

# %%
df.dropna(inplace=True) # supprimer les lignes avec des valeurs manquantes
df.isnull().sum()
# Out:
# id_ligne           0
# id_commande        0
# date_commande      0
# date_expédition    0
# mode_livraison     0
# id_client          0
# nom_client         0
# segment_client     0
# pays               0
# ville              0
# état               0
# code_postal        0
# région             0
# id_produit         0
# catégorie          0
# sous-catégorie     0
# nom_produit        0
# ventes             0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

df.duplicated() # lignes dupliquées
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9795    False
# 9796    False
# 9797    False
# 9798    False
# 9799    False
# Length: 9789, dtype: bool

# %%
df["date_commande"].dtype
# Out:
# dtype('O')

# %%
df["date_expédition"].dtype
# Out:
# dtype('O')

# %% [markdown]
# Les dates ne sont pas au bon format, alors nous allons changer le types pour des dates

# %%
df["date_expédition"] = pd.to_datetime(df["date_expédition"], format='%d/%m/%Y')
df["date_commande"] = pd.to_datetime(df["date_commande"], format='%d/%m/%Y')

# %%
print(df["date_expédition"].dtype)
print(df["date_commande"].dtype)
# Out:
# datetime64[ns]
# datetime64[ns]

# %%
df
# Out:
#       id_ligne     id_commande date_commande date_expédition  mode_livraison  \
# 0            1  CA-2017-152156    2017-11-08      2017-11-11    Second Class
# 1            2  CA-2017-152156    2017-11-08      2017-11-11    Second Class
# 2            3  CA-2017-138688    2017-06-12      2017-06-16    Second Class
# 3            4  US-2016-108966    2016-10-11      2016-10-18  Standard Class
# 4            5  US-2016-108966    2016-10-11      2016-10-18  Standard Class
# ...        ...             ...           ...             ...             ...
# 9795      9796  CA-2017-125920    2017-05-21      2017-05-28  Standard Class
# 9796      9797  CA-2016-128608    2016-01-12      2016-01-17  Standard Class
# 9797      9798  CA-2016-128608    2016-01-12      2016-01-17  Standard Class
# 9798      9799  CA-2016-128608    2016-01-12      2016-01-17  Standard Class
# 9799      9800  CA-2016-128608    2016-01-12      2016-01-17  Standard Class
#
#      id_client        nom_client segment_client           pays  \
# 0     CG-12520       Claire Gute       Consumer  United States
# 1     CG-12520       Claire Gute       Consumer  United States
# 2     DV-13045   Darrin Van Huff      Corporate  United States
# 3     SO-20335    Sean O'Donnell       Consumer  United States
# 4     SO-20335    Sean O'Donnell       Consumer  United States
# ...        ...               ...            ...            ...
# 9795  SH-19975     Sally Hughsby      Corporate  United States
# 9796  CS-12490  Cindy Schnelling      Corporate  United States
# 9797  CS-12490  Cindy Schnelling      Corporate  United States
# 9798  CS-12490  Cindy Schnelling      Corporate  United States
# 9799  CS-12490  Cindy Schnelling      Corporate  United States
#
#                 ville        état  code_postal   région       id_produit  \
# 0           Henderson    Kentucky      42420.0    South  FUR-BO-10001798
# 1           Henderson    Kentucky      42420.0    South  FUR-CH-10000454
# 2         Los Angeles  California      90036.0     West  OFF-LA-10000240
# 3     Fort Lauderdale     Florida      33311.0    South  FUR-TA-10000577
# 4     Fort Lauderdale     Florida      33311.0    South  OFF-ST-10000760
# ...               ...         ...          ...      ...              ...
# 9795          Chicago    Illinois      60610.0  Central  OFF-BI-10003429
# 9796           Toledo        Ohio      43615.0     East  OFF-AR-10001374
# 9797           Toledo        Ohio      43615.0     East  TEC-PH-10004977
# 9798           Toledo        Ohio      43615.0     East  TEC-PH-10000912
# 9799           Toledo        Ohio      43615.0     East  TEC-AC-10000487
#
#             catégorie sous-catégorie  \
# 0           Furniture      Bookcases
# 1           Furniture         Chairs
# 2     Office Supplies         Labels
# 3           Furniture         Tables
# 4     Office Supplies        Storage
# ...               ...            ...
# 9795  Office Supplies        Binders
# 9796  Office Supplies            Art
# 9797       Technology         Phones
# 9798       Technology         Phones
# 9799       Technology    Accessories
#
#                                             nom_produit    ventes
# 0                     Bush Somerset Collection Bookcase  261.9600
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                        Eldon Fold 'N Roll Cart System   22.3680
# ...                                                 ...       ...
# 9795  Cardinal HOLDit! Binder Insert Strips,Extra St...    3.7980
# 9796           BIC Brite Liner Highlighters, Chisel Tip   10.3680
# 9797                                        GE 30524EE4  235.1880
# 9798           Anker 24W Portable Micro USB Car Charger   26.3760
# 9799                SanDisk Cruzer 4 GB USB Flash Drive   10.3840
#
# [9789 rows x 18 columns]

# %% [markdown]
# #Transformation des données

# %%
# Extraire l'année, le mois, le jour

df["Année Commande"] = df["date_commande"].dt.year
df["Mois Commande"] = df["date_commande"].dt.month
df["Jour Commande"] = df["date_commande"].dt.day

# %%
# le délai de livraison

df["Délai Livraison"] = (df["date_expédition"] - df["date_commande"]).dt.days

# %%
df["Mois Commande"] = df["date_commande"].dt.strftime("%B %Y")

# %%
df.head(5)
# Out:
#    id_ligne     id_commande date_commande date_expédition  mode_livraison  \
# 0         1  CA-2017-152156    2017-11-08      2017-11-11    Second Class
# 1         2  CA-2017-152156    2017-11-08      2017-11-11    Second Class
# 2         3  CA-2017-138688    2017-06-12      2017-06-16    Second Class
# 3         4  US-2016-108966    2016-10-11      2016-10-18  Standard Class
# 4         5  US-2016-108966    2016-10-11      2016-10-18  Standard Class
#
#   id_client       nom_client segment_client           pays            ville  \
# 0  CG-12520      Claire Gute       Consumer  United States        Henderson
# 1  CG-12520      Claire Gute       Consumer  United States        Henderson
# 2  DV-13045  Darrin Van Huff      Corporate  United States      Los Angeles
# 3  SO-20335   Sean O'Donnell       Consumer  United States  Fort Lauderdale
# 4  SO-20335   Sean O'Donnell       Consumer  United States  Fort Lauderdale
#
#    ... région       id_produit        catégorie sous-catégorie  \
# 0  ...  South  FUR-BO-10001798        Furniture      Bookcases
# 1  ...  South  FUR-CH-10000454        Furniture         Chairs
# 2  ...   West  OFF-LA-10000240  Office Supplies         Labels
# 3  ...  South  FUR-TA-10000577        Furniture         Tables
# 4  ...  South  OFF-ST-10000760  Office Supplies        Storage
#
#                                          nom_produit    ventes Année Commande  \
# 0                  Bush Somerset Collection Bookcase  261.9600           2017
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400           2017
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200           2017
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775           2016
# 4                     Eldon Fold 'N Roll Cart System   22.3680           2016
#
#    Mois Commande  Jour Commande Délai Livraison
# 0  November 2017              8               3
# 1  November 2017              8               3
# 2      June 2017             12               4
# 3   October 2016             11               7
# 4   October 2016             11               7
#
# [5 rows x 22 columns]

# %% [markdown]
# # Créer un schéma en étoile

# %%
Dim_Lieu = df[['pays', 'ville', 'état', 'région', 'code_postal']].drop_duplicates().reset_index(drop=True)
Dim_Lieu['id_lieu'] = Dim_Lieu.index + 1  # Création d'un identifiant unique
Dim_Lieu.head(5)
# Out:
#             pays            ville            état région  code_postal  id_lieu
# 0  United States        Henderson        Kentucky  South      42420.0        1
# 1  United States      Los Angeles      California   West      90036.0        2
# 2  United States  Fort Lauderdale         Florida  South      33311.0        3
# 3  United States      Los Angeles      California   West      90032.0        4
# 4  United States          Concord  North Carolina  South      28027.0        5

# %%
# Merge pour ajouter id_lieu dans le DataFrame d'origine
df_lieu = df.merge(Dim_Lieu, on=['pays', 'ville', 'état', 'région', 'code_postal'], how='left')

# %%
Faits_Ventes = df_lieu[[
    'id_ligne', 'id_commande', 'id_client', 'id_produit',
    'date_commande', 'ventes', 'Délai Livraison', 'id_lieu'
]]


Faits_Ventes.head(5)
# Out:
#    id_ligne     id_commande id_client       id_produit date_commande  \
# 0         1  CA-2017-152156  CG-12520  FUR-BO-10001798    2017-11-08
# 1         2  CA-2017-152156  CG-12520  FUR-CH-10000454    2017-11-08
# 2         3  CA-2017-138688  DV-13045  OFF-LA-10000240    2017-06-12
# 3         4  US-2016-108966  SO-20335  FUR-TA-10000577    2016-10-11
# 4         5  US-2016-108966  SO-20335  OFF-ST-10000760    2016-10-11
#
#      ventes  Délai Livraison  id_lieu
# 0  261.9600                3        1
# 1  731.9400                3        1
# 2   14.6200                4        2
# 3  957.5775                7        3
# 4   22.3680                7        3

# %%
Dim_Temps = df[[
    'date_commande', 'Année Commande', 'Mois Commande', 'Jour Commande'
]].drop_duplicates().rename(columns={
    'date_commande': 'id_date',
    'Année Commande': 'année',
    'Mois Commande': 'mois',
    'Jour Commande': 'jour'
})
Dim_Temps.shape
# Out:
# (1229, 4)

# %%
Dim_Client = df_lieu[['id_client', 'nom_client', 'segment_client', 'id_lieu']].drop_duplicates()
Dim_Client.head(5)
# Out:
#    id_client       nom_client segment_client  id_lieu
# 0   CG-12520      Claire Gute       Consumer        1
# 2   DV-13045  Darrin Van Huff      Corporate        2
# 3   SO-20335   Sean O'Donnell       Consumer        3
# 5   BH-11710  Brosina Hoffman       Consumer        4
# 12  AA-10480     Andrew Allen       Consumer        5

# %%
Dim_Produit = df[['id_produit', 'nom_produit', 'catégorie', 'sous-catégorie']].drop_duplicates()

# %%
Dim_Commande = df[['id_commande', 'date_commande', 'date_expédition', 'mode_livraison','Délai Livraison']].drop_duplicates()

# %% [markdown]
# 🧠 Résumé du schéma en étoile produit
# Fait principal : Faits_Ventes (mesures : ventes, délai livraison)
#
# Dimensions reliées :
#
# Dim_Client
#
# Dim_Produit
#
# Dim_Lieu
#
# Dim_Commande
#
# Dim_Temps

# %% [markdown]
# # Exporter chaque table en CSV

# %%
# Exporter chaque table en CSV
Dim_Lieu.to_csv("Dim_Lieu.csv", index=False)
df_lieu.to_csv("df_lieu.csv", index=False)
Faits_Ventes.to_csv("Faits_Ventes.csv", index=False)
Dim_Temps.to_csv("Dim_Temps.csv", index=False)
Dim_Client.to_csv("Dim_Client.csv", index=False)
Dim_Produit.to_csv("Dim_Produit.csv", index=False)
Dim_Commande.to_csv("Dim_Commande.csv", index=False)

# %%
# 2. Téléchargement automatique (pour Google Colab uniquement)
from google.colab import files

files.download("Dim_Lieu.csv")
files.download("df_lieu.csv")
files.download("Faits_Ventes.csv")
files.download("Dim_Temps.csv")
files.download("Dim_Client.csv")
files.download("Dim_Produit.csv")
files.download("Dim_Commande.csv")
